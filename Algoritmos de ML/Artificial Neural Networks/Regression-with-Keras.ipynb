# %% [markdown]
# # REGRESSION MODELS WITH KERAS

# %% [markdown]
# ## Introducción

# %% [markdown]
# A pesar de la popularidad de otras librerías más potentes como Pytorch o TensorFlow, estas no son fáciles de usar ni tienen una suave curva de aprendizaje. Por eso, para gente que esta empezando en el deep learning (como yo), la mejor opción es usar Keras.
# Keras es una API de alto nivel para construir modelos de deep learning. Es de sintaxis fácil lo que facilita un rápido desarrollo. Vamos a ver como con Keras, construir una red neuronal compleja nos puede costar tan solo unas pocas líneas de código.

# %% [markdown]
# ## Objetivos
# * Como usar la libería Keras para construir un modelo de regresión.
# * Descargar y limpiar un dataset
# * Construir una red neuronal
# * Entrenarla y testearla

# %% [markdown]
# #### Para usar Keras tenemos que installar un framework de Backend
# (Si instalamos TensorFlow 2.16 o por encima, se instalará Keras por defecto)

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
#Importación de liberías y módulos
import pandas as pd
import numpy as np
import keras

import warnings
warnings.simplefilter('ignore', FutureWarning)
# Out:
# c:\Users\ronge\Desktop\PROGRAMACION\DATA SCIENCE\Teoría ML\.venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %% [markdown]
# El data set que usaremos es sobre la fuerza compresiva de diferentes muestras de concreto basadas en el volumen de diferentes ingredientes que usamos para hacerlos:
#
#
#
# * Cement
# * Blast furnace slag
# * Fly ash
# * Water
# * Superplasticizer
# * Coarse aggregate
# * Fine aggregate

# %% [markdown]
# ## Descargar y limpiar el Data set

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# Aquí vamos una imagen general del data set:

# %%
concrete_data.shape #su forma (filas y columnas)
# Out:
# (1030, 9)

# %% [markdown]
# Obtenemos una descripción general y comprobamos si hay valores nulos:

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# (Como hemos cogido un data set prefabricado es normal que esté bastante limpio ya)

# %% [markdown]
# #### Separación de los datos en predictors y target

# %% [markdown]
# La variable target será la fuerza de compresión y los predictores las otras columnas.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] #todas las columnas menos Strengh
target = concrete_data['Strength'] # La columna Strengh

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# Breve comprobación de que hemos separado bien:

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Normalización de los datos quitando la media y dividiendo por la desviación standard:

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# (Vamos a guardar el número de predictores en n_cols porque luego lo necesitaremos para construir nuestra red)

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# ## Construir una red neuronal

# %% [markdown]
# Vamos a definir una función que construya nuestro modelo de regresión para que luego podeamos llamarla:

# %%
def regression_model():
    # crear el modelo
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compilar el modelo
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# La función crea un modelo con dos hidden layers, cada uno con 50 nodos.

# %% [markdown]
# ## Entrenar y testear la red

# %% [markdown]
# Creación del modelo llamando a la función

# %%
model = regression_model()

# %% [markdown]
# Entrenamos y testeamos el modelo al mismo tiempo usando el método fit. Dejamos el 30% de los datos para la validación y entrenamos el modelo para 100 épocas.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 31ms/step - loss: 1569.3243 - val_loss: 1055.7100
# Epoch 2/100
# 23/23 - 0s - 5ms/step - loss: 1361.3019 - val_loss: 864.7631
# Epoch 3/100
# 23/23 - 0s - 4ms/step - loss: 1040.5513 - val_loss: 610.1065
# Epoch 4/100
# 23/23 - 0s - 4ms/step - loss: 655.7473 - val_loss: 363.7569
# Epoch 5/100
# 23/23 - 0s - 4ms/step - loss: 357.4196 - val_loss: 217.6292
# Epoch 6/100
# 23/23 - 0s - 4ms/step - loss: 243.9511 - val_loss: 179.4260
# Epoch 7/100
# 23/23 - 0s - 4ms/step - loss: 223.6265 - val_loss: 173.9593
# Epoch 8/100
# 23/23 - 0s - 4ms/step - loss: 210.8744 - val_loss: 174.8259
# Epoch 9/100
# Epoch 76/100
# 23/23 - 0s - 5ms/step - loss: 52.6868 - val_loss: 127.7408
# Epoch 77/100
# 23/23 - 0s - 4ms/step - loss: 51.4550 - val_loss: 140.9339
# Epoch 78/100
# 23/23 - 0s - 4ms/step - loss: 49.7533 - val_loss: 130.9030
# Epoch 79/100
# 23/23 - 0s - 5ms/step - loss: 48.9416 - val_loss: 131.2219
# Epoch 80/100
# 23/23 - 0s - 4ms/step - loss: 48.0350 - val_loss: 131.8237
# Epoch 81/100
# 23/23 - 0s - 4ms/step - loss: 47.3965 - val_loss: 142.2254
# Epoch 82/100
# 23/23 - 0s - 4ms/step - loss: 46.4276 - val_loss: 135.6714
# Epoch 83/100
# 23/23 - 0s - 4ms/step - loss: 45.3650 - val_loss: 140.0813
# Epoch 84/100
# 23/23 - 0s - 4ms/step - loss: 44.5690 - val_loss: 131.7054
# Epoch 85/100
# 23/23 - 0s - 8ms/step - loss: 43.9248 - val_loss: 150.6634
# Epoch 86/100
# 23/23 - 0s - 6ms/step - loss: 43.3443 - val_loss: 138.2007
# Epoch 87/100
# 23/23 - 0s - 8ms/step - loss: 43.7222 - val_loss: 127.3381
# Epoch 88/100
# 23/23 - 0s - 4ms/step - loss: 42.5697 - val_loss: 147.8136
# Epoch 89/100
# 23/23 - 0s - 4ms/step - loss: 41.5450 - val_loss: 141.7793
# Epoch 90/100
# 23/23 - 0s - 4ms/step - loss: 41.0234 - val_loss: 134.9594
# Epoch 91/100
# 23/23 - 0s - 4ms/step - loss: 40.5435 - val_loss: 142.7290
# Epoch 92/100
# 23/23 - 0s - 10ms/step - loss: 39.6529 - val_loss: 139.2121
# Epoch 93/100
# 23/23 - 0s - 6ms/step - loss: 39.5613 - val_loss: 141.8014
# Epoch 94/100
# 23/23 - 0s - 4ms/step - loss: 39.0250 - val_loss: 144.5258
# Epoch 95/100
# 23/23 - 0s - 4ms/step - loss: 38.4624 - val_loss: 138.0525
# Epoch 96/100
# 23/23 - 0s - 8ms/step - loss: 38.2521 - val_loss: 147.3945
# Epoch 97/100
# 23/23 - 0s - 5ms/step - loss: 38.3541 - val_loss: 155.8656
# Epoch 98/100
# 23/23 - 0s - 4ms/step - loss: 38.0769 - val_loss: 148.7398
# Epoch 99/100
# 23/23 - 0s - 4ms/step - loss: 37.1783 - val_loss: 143.3366
# Epoch 100/100
# 23/23 - 0s - 4ms/step - loss: 36.7187 - val_loss: 146.2010

# %% [markdown]
# ## Ejercicio práctico 1

# %% [markdown]
# Ahora usando el mismo dataset, vamos a intentar crear un modelo de regresión lineal con 5 hidden layers, cada uno con 50 nodes y ReLU como función de activación, un único output layer y todo optimizado con el Adam.

# %%
def regression_model():
    # crear el modelo
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compilar el modelo
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# ## Ejercicio práctico 2

# %% [markdown]
# Ahora entrenamos y evaluamos el modelo reservando únicamente 10% de datos para la validación.

# %%
model = regression_model()

model.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 29/29 - 1s - 45ms/step - loss: 1495.8284 - val_loss: 878.6647
# Epoch 2/100
# 29/29 - 0s - 4ms/step - loss: 587.7454 - val_loss: 195.2017
# Epoch 3/100
# 29/29 - 0s - 4ms/step - loss: 226.0130 - val_loss: 183.8313
# Epoch 4/100
# 29/29 - 0s - 4ms/step - loss: 196.2491 - val_loss: 168.0079
# Epoch 5/100
# 29/29 - 0s - 4ms/step - loss: 173.3792 - val_loss: 157.4657
# Epoch 6/100
# 29/29 - 0s - 4ms/step - loss: 156.0969 - val_loss: 146.6268
# Epoch 7/100
# 29/29 - 0s - 4ms/step - loss: 138.6860 - val_loss: 128.2925
# Epoch 8/100
# 29/29 - 0s - 4ms/step - loss: 123.3256 - val_loss: 117.7967
# Epoch 9/100
# 29/29 - 0s - 3ms/step - loss: 107.6936 - val_loss: 98.3768
# Epoch 10/100
# 29/29 - 0s - 4ms/step - loss: 94.8238 - val_loss: 91.1448
# Epoch 11/100
# 29/29 - 0s - 4ms/step - loss: 84.4751 - val_loss: 85.5714
# Epoch 12/100
# 29/29 - 0s - 4ms/step - loss: 76.5931 - val_loss: 78.6386
# Epoch 13/100
# 29/29 - 0s - 3ms/step - loss: 66.8098 - val_loss: 70.8301
# Epoch 14/100
# 29/29 - 0s - 3ms/step - loss: 59.4086 - val_loss: 70.6151
# Epoch 15/100
# 29/29 - 0s - 3ms/step - loss: 54.7676 - val_loss: 56.0758
# Epoch 16/100
# 29/29 - 0s - 3ms/step - loss: 51.9076 - val_loss: 55.4074
# Epoch 17/100
# 29/29 - 0s - 3ms/step - loss: 47.0539 - val_loss: 43.1109
# Epoch 18/100
# 29/29 - 0s - 3ms/step - loss: 45.4365 - val_loss: 45.0020
# Epoch 19/100
# 29/29 - 0s - 4ms/step - loss: 43.0621 - val_loss: 41.7355
# Epoch 20/100
# 29/29 - 0s - 4ms/step - loss: 42.0959 - val_loss: 38.9749
# Epoch 21/100
# 29/29 - 0s - 4ms/step - loss: 38.1798 - val_loss: 32.9450
# Epoch 22/100
# 29/29 - 0s - 4ms/step - loss: 35.7104 - val_loss: 31.5474
# Epoch 23/100
# 29/29 - 0s - 4ms/step - loss: 33.4100 - val_loss: 33.5874
# Epoch 24/100
# 29/29 - 0s - 4ms/step - loss: 31.8048 - val_loss: 29.6869
# Epoch 25/100
# 29/29 - 0s - 3ms/step - loss: 31.1413 - val_loss: 28.5627
# Epoch 26/100
# 29/29 - 0s - 3ms/step - loss: 30.1511 - val_loss: 27.2504
# Epoch 27/100
# 29/29 - 0s - 3ms/step - loss: 27.8690 - val_loss: 27.6956
# Epoch 28/100
# 29/29 - 0s - 3ms/step - loss: 27.0737 - val_loss: 26.8285
# Epoch 29/100
# 29/29 - 0s - 4ms/step - loss: 25.7527 - val_loss: 28.1329
# Epoch 30/100
# 29/29 - 0s - 4ms/step - loss: 25.4367 - val_loss: 24.8974
# Epoch 31/100
# 29/29 - 0s - 4ms/step - loss: 26.2464 - val_loss: 26.6826
# Epoch 32/100
# 29/29 - 0s - 3ms/step - loss: 24.5271 - val_loss: 28.9071
# Epoch 33/100
# 29/29 - 0s - 4ms/step - loss: 23.0142 - val_loss: 24.2467
# Epoch 34/100
# 29/29 - 0s - 6ms/step - loss: 23.1226 - val_loss: 23.3282
# Epoch 35/100
# 29/29 - 0s - 3ms/step - loss: 21.9642 - val_loss: 24.1309
# Epoch 36/100
# 29/29 - 0s - 3ms/step - loss: 21.9177 - val_loss: 21.6957
# Epoch 37/100
# 29/29 - 0s - 3ms/step - loss: 22.0647 - val_loss: 21.9326
# Epoch 38/100
# 29/29 - 0s - 4ms/step - loss: 21.7489 - val_loss: 26.3548
# Epoch 39/100
# 29/29 - 0s - 4ms/step - loss: 21.7884 - val_loss: 21.7311
# Epoch 40/100
# 29/29 - 0s - 4ms/step - loss: 21.4031 - val_loss: 22.4698
# Epoch 41/100
# 29/29 - 0s - 3ms/step - loss: 22.0202 - val_loss: 20.4090
# Epoch 42/100
# 29/29 - 0s - 4ms/step - loss: 19.9795 - val_loss: 23.6470
# Epoch 43/100
# 29/29 - 0s - 4ms/step - loss: 19.1340 - val_loss: 20.4868
# Epoch 44/100
# 29/29 - 0s - 4ms/step - loss: 19.1071 - val_loss: 20.1255
# Epoch 45/100
# 29/29 - 0s - 4ms/step - loss: 20.8829 - val_loss: 19.2679
# Epoch 46/100
# 29/29 - 0s - 3ms/step - loss: 18.7345 - val_loss: 19.8975
# Epoch 47/100
# 29/29 - 0s - 4ms/step - loss: 18.9894 - val_loss: 19.5918
# Epoch 48/100
# 29/29 - 0s - 4ms/step - loss: 17.8686 - val_loss: 20.1070
# Epoch 49/100
# 29/29 - 0s - 4ms/step - loss: 19.3785 - val_loss: 25.3376
# Epoch 50/100
# 29/29 - 0s - 4ms/step - loss: 17.4348 - val_loss: 26.4731
# Epoch 51/100
# 29/29 - 0s - 5ms/step - loss: 17.2148 - val_loss: 21.1309
# Epoch 52/100
# 29/29 - 0s - 4ms/step - loss: 17.7757 - val_loss: 20.1220
# Epoch 53/100
# 29/29 - 0s - 4ms/step - loss: 18.4754 - val_loss: 23.7039
# Epoch 54/100
# 29/29 - 0s - 4ms/step - loss: 16.4917 - val_loss: 19.6156
# Epoch 55/100
# 29/29 - 0s - 4ms/step - loss: 18.8657 - val_loss: 17.7890
# Epoch 56/100
# 29/29 - 0s - 4ms/step - loss: 17.9347 - val_loss: 23.5934
# Epoch 57/100
# 29/29 - 0s - 5ms/step - loss: 17.3989 - val_loss: 21.5312
# Epoch 58/100
# 29/29 - 0s - 4ms/step - loss: 17.2389 - val_loss: 17.8485
# Epoch 59/100
# 29/29 - 0s - 4ms/step - loss: 17.7985 - val_loss: 20.9161
# Epoch 60/100
# 29/29 - 0s - 4ms/step - loss: 17.0164 - val_loss: 18.7658
# Epoch 61/100
# 29/29 - 0s - 4ms/step - loss: 16.1268 - val_loss: 19.6395
# Epoch 62/100
# 29/29 - 0s - 4ms/step - loss: 16.7570 - val_loss: 19.4628
# Epoch 63/100
# 29/29 - 0s - 4ms/step - loss: 15.7979 - val_loss: 19.3512
# Epoch 64/100
# 29/29 - 0s - 4ms/step - loss: 16.3368 - val_loss: 17.1392
# Epoch 65/100
# 29/29 - 0s - 4ms/step - loss: 15.7916 - val_loss: 19.7553
# Epoch 66/100
# 29/29 - 0s - 3ms/step - loss: 16.9867 - val_loss: 17.0287
# Epoch 67/100
# 29/29 - 0s - 3ms/step - loss: 16.8490 - val_loss: 17.3593
# Epoch 68/100
# 29/29 - 0s - 3ms/step - loss: 15.9834 - val_loss: 17.7413
# Epoch 69/100
# 29/29 - 0s - 3ms/step - loss: 14.5873 - val_loss: 17.9511
# Epoch 70/100
# 29/29 - 0s - 3ms/step - loss: 14.5766 - val_loss: 15.9741
# Epoch 71/100
# 29/29 - 0s - 3ms/step - loss: 16.2764 - val_loss: 16.0610
# Epoch 72/100
# 29/29 - 0s - 3ms/step - loss: 15.4671 - val_loss: 21.4235
# Epoch 73/100
# 29/29 - 0s - 3ms/step - loss: 14.0725 - val_loss: 23.5750
# Epoch 74/100
# 29/29 - 0s - 3ms/step - loss: 16.3374 - val_loss: 17.3280
# Epoch 75/100
# 29/29 - 0s - 3ms/step - loss: 14.3422 - val_loss: 16.0179
# Epoch 76/100
# 29/29 - 0s - 3ms/step - loss: 13.5399 - val_loss: 16.9031
# Epoch 77/100
# 29/29 - 0s - 3ms/step - loss: 14.1679 - val_loss: 15.9347
# Epoch 78/100
# 29/29 - 0s - 3ms/step - loss: 15.0100 - val_loss: 17.0962
# Epoch 79/100
# 29/29 - 0s - 3ms/step - loss: 15.4645 - val_loss: 16.8653
# Epoch 80/100
# 29/29 - 0s - 3ms/step - loss: 14.6886 - val_loss: 17.6777
# Epoch 81/100
# 29/29 - 0s - 3ms/step - loss: 13.2955 - val_loss: 14.7728
# Epoch 82/100
# 29/29 - 0s - 3ms/step - loss: 13.4304 - val_loss: 23.9805
# Epoch 83/100
# 29/29 - 0s - 3ms/step - loss: 15.2153 - val_loss: 15.8971
# Epoch 84/100
# 29/29 - 0s - 3ms/step - loss: 13.4778 - val_loss: 16.5571
# Epoch 85/100
# 29/29 - 0s - 3ms/step - loss: 14.2685 - val_loss: 15.5554
# Epoch 86/100
# 29/29 - 0s - 3ms/step - loss: 16.4574 - val_loss: 15.9434
# Epoch 87/100
# 29/29 - 0s - 3ms/step - loss: 14.1263 - val_loss: 14.9919
# Epoch 88/100
# 29/29 - 0s - 3ms/step - loss: 13.6997 - val_loss: 19.9557
# Epoch 89/100
# 29/29 - 0s - 3ms/step - loss: 13.1196 - val_loss: 15.5983
# Epoch 90/100
# 29/29 - 0s - 4ms/step - loss: 13.0392 - val_loss: 15.2594
# Epoch 91/100
# 29/29 - 0s - 3ms/step - loss: 13.1199 - val_loss: 13.5337
# Epoch 92/100
# 29/29 - 0s - 3ms/step - loss: 15.1058 - val_loss: 23.3044
# Epoch 93/100
# 29/29 - 0s - 3ms/step - loss: 13.6980 - val_loss: 14.6115
# Epoch 94/100
# 29/29 - 0s - 3ms/step - loss: 12.2896 - val_loss: 16.4437
# Epoch 95/100
# 29/29 - 0s - 3ms/step - loss: 13.0719 - val_loss: 13.2449
# Epoch 96/100
# 29/29 - 0s - 3ms/step - loss: 12.0028 - val_loss: 13.3579
# Epoch 97/100
# 29/29 - 0s - 3ms/step - loss: 12.3899 - val_loss: 18.1944
# Epoch 98/100
# 29/29 - 0s - 3ms/step - loss: 12.1348 - val_loss: 15.0064
# Epoch 99/100
# 29/29 - 0s - 3ms/step - loss: 12.0267 - val_loss: 17.7469
# Epoch 100/100
# 29/29 - 0s - 4ms/step - loss: 12.5292 - val_loss: 13.0796

# %% [markdown]
# Basándonos en los resultados, notamos que:
# - Añadir más hidden layers al modelo aumenta su capacidad para aprender y representar relaciones complejas entre los datos.
# - Reducir la propoción de datos seleccionados para la validación supone aumentar la cantidad de datos para el entrenamiento, lo que permite al modelo acceso a más ejemplos de los que aprender.
